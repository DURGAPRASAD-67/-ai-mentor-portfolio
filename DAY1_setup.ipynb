# %% [markdown]
# <a href="https://colab.research.google.com/github/DURGAPRASAD-67/-ai-mentor-portfolio/blob/main/DAY1_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: '
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid describes the diverse talent needed in the AI ecosystem, from fundamental research to broad application and literacy. Here are its layers explained in 4 points, from top to bottom:
#
# *   **Top (AI Innovators):** A small group focused on fundamental research, creating new AI theories, algorithms, and pushing the boundaries of the field (e.g., AI scientists, PhD researchers).
# *   **Upper-Mid (AI Developers/Engineers):** Build, deploy, and maintain AI systems and applications, translating research into practical, production-ready solutions (e.g., ML engineers, data scientists).
# *   **Lower-Mid (AI Professionals/Domain Experts):** Apply AI tools and insights to specific business problems, interpret results, and guide AI integration within their fields (e.g., product managers with AI acumen, business analysts).
# *   **Base (AI Users & AI-Ready Workforce):** The largest group, encompassing those who utilize AI-powered products for everyday tasks and the general workforce needing basic AI literacy and awareness (e.g., software users, employees understanding AI impact).
